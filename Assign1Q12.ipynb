# %% [markdown]
# Assignment 1 Q 12

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.Series([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56 ])

# %%
df
# Out:
# 0     34
# 1     36
# 2     36
# 3     38
# 4     38
# 5     39
# 6     39
# 7     40
# 8     40
# 9     41
# 10    41
# 11    41
# 12    41
# 13    42
# 14    42
# 15    45
# 16    49
# 17    56
# dtype: int64

# %%
#mean
df.mean()
# Out:
# 41.0

# %%
#median
df.median()
# Out:
# 40.5

# %%
# variance
df.var()
# Out:
# 25.529411764705884

# %%
#standard deviation
df.std()
# Out:
# 5.05266382858645

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc341db4f90>,
#   <matplotlib.lines.Line2D at 0x7fc341dbf510>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc341dbfa50>,
#   <matplotlib.lines.Line2D at 0x7fc341dbff90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc341db4990>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc341dc7550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc341e1ff10>],
#  'means': []}
